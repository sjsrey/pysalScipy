# %%
import numpy as np
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## X,Y Plots

# %%
d = np.linspace(1,10,200)
I = np.exp(-d)
plot(d,I)

# %%
d = np.linspace(1,10,200)
I = np.exp(-d)
plot(d,I)
ylabel('I')
xlabel('d')

# %%
d = np.linspace(1,10,200)
I = np.exp(-d)
plot(d,I)
ylabel(r'$I= \exp(-d)$')
xlabel('d')

# %%
type(d)
d[0:10]
# Out:
# array([ 1.        ,  1.04522613,  1.09045226,  1.13567839,  1.18090452,
#         1.22613065,  1.27135678,  1.31658291,  1.36180905,  1.40703518])

# %%
d = np.linspace(1,10,200)
I = d**(-2)
plot(d,I)
ylabel(r'$I= 1 / d^2$')
xlabel('d')

# %%
d = np.linspace(1,10,200)
Iid2 = d**(-2)
plot(d,Iid2)
ylabel(r'$I$')
Inex = np.exp(-d)
plot(d,Inex)
xlabel('d')

# %%
d = np.linspace(1,10,200)
Iid2 = d**(-2)
plot(d,Iid2, label = r'$I = d^{-2}$')
ylabel(r'$I$')
Inex = np.exp(-d)
plot(d,Inex, label = r'$I = \exp(-d)$')
xlabel('d')
legend()

# %%
legend?

# %%
legen
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-fc4fac902274> in <module>()
# ----> 1 legen
#
# NameError: name 'legen' is not defined

# %%
d = np.linspace(1,10,200)
Iid2 = d**(-2)
plot(d,Iid2, 'r-', label = r'$I = d^{-2}$')
ylabel(r'$I$')
Inex = np.exp(-d)
plot(d,Inex, 'g--',label = r'$I = \exp(-d)$')
xlabel('d')
legend()

# %%
d = np.linspace(1,10,200)
Iid = d**(-1)
plot(d,Iid, 'b-.', label = r'$I = d^{-1}$')
Iid2 = d**(-2)
plot(d,Iid2, 'r-', label = r'$I = d^{-2}$')
ylabel(r'$I$')
Inex = np.exp(-d)
plot(d,Inex, 'g--',label = r'$I = \exp(-d)$')
xlabel('d')
legend()
title('Distance Decay')

# %% [markdown]
# ## Scatter Plot

# %%
x = np.arange(100)
y = 0.5 + np.random.normal(size=(100,))
scatter(x,y)
xlabel('x')
ylabel('y')

# %%
scatter(x,y)
vlines(x.mean(),y.min(),y.max())
hlines(x.min(),x.max(),y.mean())

# %% [markdown]
# ## Distributions and Densities

# %%
import numpy as np

x = np.random.multivariate_normal([100,70],[[2.,1.7],[1.7,2.]], (50))

# %%
x
# Out:
# array([[  99.65365959,   68.9578577 ],
#        [  96.47487931,   66.1610249 ],
#        [  99.62066424,   69.31973538],
#        [  98.57380397,   68.49890867],
#        [  98.55296273,   69.72449571],
#        [ 100.35810849,   70.22032659],
#        [  98.71201577,   69.45252927],
#        [  97.67860901,   68.5050542 ],
#        [  99.73389153,   69.58113806],
#        [  98.98260093,   68.72888945],
#        [ 102.93642986,   71.40564748],
#        [  98.52348305,   69.59937772],
#        [  98.43735234,   69.30807995],
#        [  99.19520396,   68.88153333],
#        [ 100.74643553,   70.33864763],
#        [ 100.84086682,   70.72173873],
#        [ 101.29569339,   71.1357403 ],
#        [ 100.7086912 ,   71.20754928],
#        [ 100.04540004,   70.71174324],
#        [ 100.01635683,   70.157597  ],
#        [  98.90764398,   68.85212001],
#        [ 101.6138046 ,   71.66769447],
#        [  98.46167948,   68.80189209],
#        [  99.95491017,   71.32290401],
#        [  99.2314893 ,   68.72376754],
#        [  99.88768152,   69.26305223],
#        [ 102.66970715,   72.22941842],
#        [ 101.76091891,   70.74328829],
#        [ 100.14298971,   70.36107098],
#        [  98.46025659,   69.32988453],
#        [  99.83706794,   69.85063138],
#        [ 100.12307543,   68.71070634],
#        [ 101.75135469,   72.64473845],
#        [ 101.31566672,   69.5123136 ],
#        [ 100.3825537 ,   70.54208418],
#        [ 100.94632126,   70.57187206],
#        [ 100.94204428,   71.72492324],
#        [  98.46630888,   68.67010365],
#        [ 101.19841544,   70.01489597],
#        [ 100.67328111,   70.02642184],
#        [ 100.62249487,   71.7040704 ],
#        [ 100.40563812,   71.4394701 ],
#        [  98.12310924,   69.04295196],
#        [  99.21092544,   69.80399822],
#        [ 100.09697733,   70.08033521],
#        [  98.94334785,   69.08370937],
#        [  99.21943157,   69.64360384],
#        [  98.15998341,   68.24432101],
#        [  99.71248351,   69.23038484],
#        [ 102.49093675,   70.61613815]])

# %%
plot(x)
# Out:
# [<matplotlib.lines.Line2D at 0x7f530a035490>,
#  <matplotlib.lines.Line2D at 0x7f530a035710>]

# %%
plot(x[:,0], x[:,1], "o")

# %%
x0h = hist(x[:,0])

# %%
x1h = hist(x[:,1])

# %%
n,bins,bars = hist(x[:,1])

y = normpdf(bins, mean(x[:,1]), std(x[:,1]))

# %%
plot(bins,y)

# %%
plot(bins,y)
hist(x[:,1])
# Out:
# (array([  1.,   0.,   0.,   7.,  11.,  10.,   8.,   6.,   5.,   2.]),
#  array([ 66.1610249 ,  66.80939626,  67.45776761,  68.10613897,
#          68.75451032,  69.40288168,  70.05125303,  70.69962439,
#          71.34799574,  71.9963671 ,  72.64473845]),
#  <a list of 10 Patch objects>)

# %%
plot(bins,y)
hist(x[:,1],normed=1)
# Out:
# (array([ 0.03084652,  0.        ,  0.        ,  0.21592564,  0.33931172,
#          0.3084652 ,  0.24677216,  0.18507912,  0.1542326 ,  0.06169304]),
#  array([ 66.1610249 ,  66.80939626,  67.45776761,  68.10613897,
#          68.75451032,  69.40288168,  70.05125303,  70.69962439,
#          71.34799574,  71.9963671 ,  72.64473845]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Saving to a file

# %%
plot(bins,y)
hist(x[:,1],normed=1)
savefig("hist.png")

# %%
# !ls *.png
# Out:
# hist.png

# %%
from scipy.stats import gaussian_kde

# %%
y = x[:,1]
density = gaussian_kde(y)

# %%
xs = np.linspace(y.min(),y.max(),30)
plot(xs, density(xs))
xlabel('y')
ylabel('f(y)')

# %%
xs = np.linspace(y.min()*.8,y.max()*1.2,30)
plot(xs, density(xs))
xlabel('y')
ylabel('f(y)')

# %% [markdown]
# There is a lot more to matplotlib. One can visit the [gallery](http://matplotlib.org/gallery.html) and pull examples in to get a sense of what is possible, and how to adapt examples for your own purposes.
#
#
# For now we move on to generating choropleth maps.
